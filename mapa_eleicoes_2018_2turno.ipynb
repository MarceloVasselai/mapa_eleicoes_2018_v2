# %% [markdown]
# # Mapa do resultado do 2º Turno das Eleições Presidencias de 2018 por Município

# %%
# Importando as bibliotecas
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Caminho para o arquivo Shapefile 
caminho_shapefile = r'D:\Usuários\Downloads\BR_Municipios_2023\BR_Municipios_2023.shp'

# Ler o Shapefile
df_mapa = gpd.read_file(caminho_shapefile)

# Exibir as primeiras linhas
df_mapa.head()
# Out:
#     CD_MUN                 NM_MUN  CD_RGI     NM_RGI CD_RGINT     NM_RGINT  \
# 0  1100015  Alta Floresta D'Oeste  110005     Cacoal     1102    Ji-Paraná
# 1  1100023              Ariquemes  110002  Ariquemes     1101  Porto Velho
# 2  1100031                 Cabixi  110006    Vilhena     1102    Ji-Paraná
# 3  1100049                 Cacoal  110005     Cacoal     1102    Ji-Paraná
# 4  1100056             Cerejeiras  110006    Vilhena     1102    Ji-Paraná
#
#   CD_UF     NM_UF CD_REGIAO NM_REGIAO CD_CONCURB NM_CONCURB  AREA_KM2  \
# 0    11  Rondônia         1     Norte       None       None  7067.127
# 1    11  Rondônia         1     Norte       None       None  4426.143
# 2    11  Rondônia         1     Norte       None       None  1314.352
# 3    11  Rondônia         1     Norte       None       None  3793.000
# 4    11  Rondônia         1     Norte       None       None  2783.297
#
#                                             geometry
# 0  POLYGON ((-61.93075 -11.97349, -61.93234 -11.9...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.56035 -13.32206, -60.52518 -13.3...
# 3  POLYGON ((-61.00075 -11.25298, -61.0008 -11.29...
# 4  POLYGON ((-60.82068 -13.11944, -60.81773 -13.1...

# %%
# Verificando o dataframe do geopandas
df_mapa.head()
# Out:
#     CD_MUN                 NM_MUN  CD_RGI     NM_RGI CD_RGINT     NM_RGINT  \
# 0  1100015  Alta Floresta D'Oeste  110005     Cacoal     1102    Ji-Paraná
# 1  1100023              Ariquemes  110002  Ariquemes     1101  Porto Velho
# 2  1100031                 Cabixi  110006    Vilhena     1102    Ji-Paraná
# 3  1100049                 Cacoal  110005     Cacoal     1102    Ji-Paraná
# 4  1100056             Cerejeiras  110006    Vilhena     1102    Ji-Paraná
#
#   CD_UF     NM_UF CD_REGIAO NM_REGIAO CD_CONCURB NM_CONCURB  AREA_KM2  \
# 0    11  Rondônia         1     Norte       None       None  7067.127
# 1    11  Rondônia         1     Norte       None       None  4426.143
# 2    11  Rondônia         1     Norte       None       None  1314.352
# 3    11  Rondônia         1     Norte       None       None  3793.000
# 4    11  Rondônia         1     Norte       None       None  2783.297
#
#                                             geometry
# 0  POLYGON ((-61.93075 -11.97349, -61.93234 -11.9...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.56035 -13.32206, -60.52518 -13.3...
# 3  POLYGON ((-61.00075 -11.25298, -61.0008 -11.29...
# 4  POLYGON ((-60.82068 -13.11944, -60.81773 -13.1...

# %%
# Verificando tamanho e colunas
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CD_MUN      5572 non-null   object
#  1   NM_MUN      5572 non-null   object
#  2   CD_RGI      5570 non-null   object
#  3   NM_RGI      5570 non-null   object
#  4   CD_RGINT    5570 non-null   object
#  5   NM_RGINT    5570 non-null   object
#  6   CD_UF       5570 non-null   object
#  7   NM_UF       5570 non-null   object
#  8   CD_REGIAO   5570 non-null   object
#  9   NM_REGIAO   5570 non-null   object
#  10  CD_CONCURB  660 non-null    object
#  11  NM_CONCURB  660 non-null    object
#  12  AREA_KM2    5572 non-null   float64
#  13  geometry    5572 non-null   geometry
# dtypes: float64(1), geometry(1), object(12)
# memory usage: 609.6+ KB

# %%
# Vamos exibir o mapa (plotar o shapefile)
df_mapa.plot()
# Out:
# <Axes: >

# %%
# Vamos expandir o espaço para desenhar o mapa
fig, ax = plt.subplots(1, figsize=(12,12))

# desenhar o mapa
df_mapa.plot(ax=ax)

# tirar os eixos
ax.set_axis_off()

plt.show()

# %%
# Vamos carregar o arquivo com o resultado da eleição no Brasil dividido por municipio/zona
df_votacao = pd.read_csv('./dados_eleicao/votacao_candidato_munzona_2018_BR.csv',
                        sep=';', encoding='latin1')

df_votacao.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Vamos carregar o arquivo com o resultado da eleição no Brasil dividido por municipio/zona
# ----> 2 df_votacao = pd.read_csv('./dados_eleicao/votacao_candidato_munzona_2018_BR.csv',
#       3                         sep=';', encoding='latin1')
#       5 df_votacao.head()
#
# File c:\Users\User\j dados\mapa_eleicoes_2018_v2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\User\j dados\mapa_eleicoes_2018_v2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\User\j dados\mapa_eleicoes_2018_v2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\User\j dados\mapa_eleicoes_2018_v2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\User\j dados\mapa_eleicoes_2018_v2\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './dados_eleicao/votacao_candidato_munzona_2018_BR.csv'

# %%
# Visualizando o dataframe transposto
df_votacao.head().T
# Out:
#                                                       0  \
# DT_GERACAO                                   02/07/2019
# HH_GERACAO                                     19:46:18
# ANO_ELEICAO                                        2018
# CD_TIPO_ELEICAO                                       2
# NM_TIPO_ELEICAO                       Eleição Ordinária
# NR_TURNO                                              1
# CD_ELEICAO                                          295
# DS_ELEICAO                   ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                   07/10/2018
# TP_ABRANGENCIA                                        F
# SG_UF                                                PR
# SG_UE                                                BR
# NM_UE                                            BRASIL
# CD_MUNICIPIO                                      75132
# NM_MUNICIPIO                                    COLOMBO
# NR_ZONA                                             186
# CD_CARGO                                              1
# DS_CARGO                                     Presidente
# SQ_CANDIDATO                               280000624082
# NR_CANDIDATO                                         54
# NM_CANDIDATO              JOÃO VICENTE FONTELLA GOULART
# NM_URNA_CANDIDATO                    JOÃO GOULART FILHO
# NM_SOCIAL_CANDIDATO                              #NULO#
# CD_SITUACAO_CANDIDATURA                              12
# DS_SITUACAO_CANDIDATURA                            APTO
# CD_DETALHE_SITUACAO_CAND                              2
# DS_DETALHE_SITUACAO_CAND                       DEFERIDO
# TP_AGREMIACAO                           Partido isolado
# NR_PARTIDO                                           54
# SG_PARTIDO                                          PPL
# NM_PARTIDO                         Partido Pátria Livre
# SQ_COLIGACAO                               280000050638
# NM_COLIGACAO                            PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                             PPL
# CD_SIT_TOT_TURNO                                      4
# DS_SIT_TOT_TURNO                             NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                   N
# QT_VOTOS_NOMINAIS                                    17
#
#                                                       1  \
# DT_GERACAO                                   02/07/2019
# HH_GERACAO                                     19:46:18
# ANO_ELEICAO                                        2018
# CD_TIPO_ELEICAO                                       2
# NM_TIPO_ELEICAO                       Eleição Ordinária
# NR_TURNO                                              1
# CD_ELEICAO                                          295
# DS_ELEICAO                   ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                   07/10/2018
# TP_ABRANGENCIA                                        F
# SG_UF                                                MG
# SG_UE                                                BR
# NM_UE                                            BRASIL
# CD_MUNICIPIO                                      44393
# NM_MUNICIPIO                                     DIVINO
# NR_ZONA                                              70
# CD_CARGO                                              1
# DS_CARGO                                     Presidente
# SQ_CANDIDATO                               280000624082
# NR_CANDIDATO                                         54
# NM_CANDIDATO              JOÃO VICENTE FONTELLA GOULART
# NM_URNA_CANDIDATO                    JOÃO GOULART FILHO
# NM_SOCIAL_CANDIDATO                              #NULO#
# CD_SITUACAO_CANDIDATURA                              12
# DS_SITUACAO_CANDIDATURA                            APTO
# CD_DETALHE_SITUACAO_CAND                              2
# DS_DETALHE_SITUACAO_CAND                       DEFERIDO
# TP_AGREMIACAO                           Partido isolado
# NR_PARTIDO                                           54
# SG_PARTIDO                                          PPL
# NM_PARTIDO                         Partido Pátria Livre
# SQ_COLIGACAO                               280000050638
# NM_COLIGACAO                            PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                             PPL
# CD_SIT_TOT_TURNO                                      4
# DS_SIT_TOT_TURNO                             NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                   N
# QT_VOTOS_NOMINAIS                                     5
#
#                                                       2  \
# DT_GERACAO                                   02/07/2019
# HH_GERACAO                                     19:46:18
# ANO_ELEICAO                                        2018
# CD_TIPO_ELEICAO                                       2
# NM_TIPO_ELEICAO                       Eleição Ordinária
# NR_TURNO                                              1
# CD_ELEICAO                                          295
# DS_ELEICAO                   ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                   07/10/2018
# TP_ABRANGENCIA                                        F
# SG_UF                                                BA
# SG_UE                                                BR
# NM_UE                                            BRASIL
# CD_MUNICIPIO                                      36676
# NM_MUNICIPIO                                    JITAÚNA
# NR_ZONA                                              24
# CD_CARGO                                              1
# DS_CARGO                                     Presidente
# SQ_CANDIDATO                               280000624082
# NR_CANDIDATO                                         54
# NM_CANDIDATO              JOÃO VICENTE FONTELLA GOULART
# NM_URNA_CANDIDATO                    JOÃO GOULART FILHO
# NM_SOCIAL_CANDIDATO                              #NULO#
# CD_SITUACAO_CANDIDATURA                              12
# DS_SITUACAO_CANDIDATURA                            APTO
# CD_DETALHE_SITUACAO_CAND                              2
# DS_DETALHE_SITUACAO_CAND                       DEFERIDO
# TP_AGREMIACAO                           Partido isolado
# NR_PARTIDO                                           54
# SG_PARTIDO                                          PPL
# NM_PARTIDO                         Partido Pátria Livre
# SQ_COLIGACAO                               280000050638
# NM_COLIGACAO                            PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                             PPL
# CD_SIT_TOT_TURNO                                      4
# DS_SIT_TOT_TURNO                             NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                   N
# QT_VOTOS_NOMINAIS                                    28
#
#                                                       3  \
# DT_GERACAO                                   02/07/2019
# HH_GERACAO                                     19:46:18
# ANO_ELEICAO                                        2018
# CD_TIPO_ELEICAO                                       2
# NM_TIPO_ELEICAO                       Eleição Ordinária
# NR_TURNO                                              1
# CD_ELEICAO                                          295
# DS_ELEICAO                   ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                   07/10/2018
# TP_ABRANGENCIA                                        F
# SG_UF                                                MS
# SG_UE                                                BR
# NM_UE                                            BRASIL
# CD_MUNICIPIO                                      90395
# NM_MUNICIPIO                                  BATAYPORÃ
# NR_ZONA                                               5
# CD_CARGO                                              1
# DS_CARGO                                     Presidente
# SQ_CANDIDATO                               280000624082
# NR_CANDIDATO                                         54
# NM_CANDIDATO              JOÃO VICENTE FONTELLA GOULART
# NM_URNA_CANDIDATO                    JOÃO GOULART FILHO
# NM_SOCIAL_CANDIDATO                              #NULO#
# CD_SITUACAO_CANDIDATURA                              12
# DS_SITUACAO_CANDIDATURA                            APTO
# CD_DETALHE_SITUACAO_CAND                              2
# DS_DETALHE_SITUACAO_CAND                       DEFERIDO
# TP_AGREMIACAO                           Partido isolado
# NR_PARTIDO                                           54
# SG_PARTIDO                                          PPL
# NM_PARTIDO                         Partido Pátria Livre
# SQ_COLIGACAO                               280000050638
# NM_COLIGACAO                            PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                             PPL
# CD_SIT_TOT_TURNO                                      4
# DS_SIT_TOT_TURNO                             NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                   N
# QT_VOTOS_NOMINAIS                                     1
#
#                                                                   4
# DT_GERACAO                                               02/07/2019
# HH_GERACAO                                                 19:46:18
# ANO_ELEICAO                                                    2018
# CD_TIPO_ELEICAO                                                   2
# NM_TIPO_ELEICAO                                   Eleição Ordinária
# NR_TURNO                                                          1
# CD_ELEICAO                                                      295
# DS_ELEICAO                               ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                               07/10/2018
# TP_ABRANGENCIA                                                    F
# SG_UF                                                            PI
# SG_UE                                                            BR
# NM_UE                                                        BRASIL
# CD_MUNICIPIO                                                  10294
# NM_MUNICIPIO                                                BATALHA
# NR_ZONA                                                          45
# CD_CARGO                                                          1
# DS_CARGO                                                 Presidente
# SQ_CANDIDATO                                           280000614517
# NR_CANDIDATO                                                     17
# NM_CANDIDATO                                 JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                    JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                          #NULO#
# CD_SITUACAO_CANDIDATURA                                          12
# DS_SITUACAO_CANDIDATURA                                        APTO
# CD_DETALHE_SITUACAO_CAND                                          2
# DS_DETALHE_SITUACAO_CAND                                   DEFERIDO
# TP_AGREMIACAO                                             Coligação
# NR_PARTIDO                                                       17
# SG_PARTIDO                                                      PSL
# NM_PARTIDO                                   Partido Social Liberal
# SQ_COLIGACAO                                           280000050386
# NM_COLIGACAO              BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                  PSL / PRTB
# CD_SIT_TOT_TURNO                                                  6
# DS_SIT_TOT_TURNO                                           2º TURNO
# ST_VOTO_EM_TRANSITO                                               N
# QT_VOTOS_NOMINAIS                                              2720

# %%
# Separar os dados pois precisamos apenas dos dados de 2 Turno
df_votacao = df_votacao[df_votacao['NR_TURNO'] == 2]

df_votacao.sample(3).T
# Out:
#                                                               2087   \
# DT_GERACAO                                               02/07/2019
# HH_GERACAO                                                 19:46:18
# ANO_ELEICAO                                                    2018
# CD_TIPO_ELEICAO                                                   2
# NM_TIPO_ELEICAO                                   Eleição Ordinária
# NR_TURNO                                                          2
# CD_ELEICAO                                                      296
# DS_ELEICAO                               ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                               28/10/2018
# TP_ABRANGENCIA                                                    F
# SG_UF                                                            RJ
# SG_UE                                                            BR
# NM_UE                                                        BRASIL
# CD_MUNICIPIO                                                  58211
# NM_MUNICIPIO                                              CANTAGALO
# NR_ZONA                                                         101
# CD_CARGO                                                          1
# DS_CARGO                                                 Presidente
# SQ_CANDIDATO                                           280000614517
# NR_CANDIDATO                                                     17
# NM_CANDIDATO                                 JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                    JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                          #NULO#
# CD_SITUACAO_CANDIDATURA                                          12
# DS_SITUACAO_CANDIDATURA                                        APTO
# CD_DETALHE_SITUACAO_CAND                                          2
# DS_DETALHE_SITUACAO_CAND                                   DEFERIDO
# TP_AGREMIACAO                                             Coligação
# NR_PARTIDO                                                       17
# SG_PARTIDO                                                      PSL
# NM_PARTIDO                                   Partido Social Liberal
# SQ_COLIGACAO                                           280000050386
# NM_COLIGACAO              BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                  PSL / PRTB
# CD_SIT_TOT_TURNO                                                  1
# DS_SIT_TOT_TURNO                                             ELEITO
# ST_VOTO_EM_TRANSITO                                               N
# QT_VOTOS_NOMINAIS                                              6886
#
#                                                58858  \
# DT_GERACAO                                02/07/2019
# HH_GERACAO                                  19:46:18
# ANO_ELEICAO                                     2018
# CD_TIPO_ELEICAO                                    2
# NM_TIPO_ELEICAO                    Eleição Ordinária
# NR_TURNO                                           2
# CD_ELEICAO                                       296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018
# TP_ABRANGENCIA                                     F
# SG_UF                                             ZZ
# SG_UE                                             BR
# NM_UE                                         BRASIL
# CD_MUNICIPIO                                   29475
# NM_MUNICIPIO                                  CAIENA
# NR_ZONA                                            1
# CD_CARGO                                           1
# DS_CARGO                                  Presidente
# SQ_CANDIDATO                            280000629808
# NR_CANDIDATO                                      13
# NM_CANDIDATO                         FERNANDO HADDAD
# NM_URNA_CANDIDATO                    FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                           #NULO#
# CD_SITUACAO_CANDIDATURA                           12
# DS_SITUACAO_CANDIDATURA                         APTO
# CD_DETALHE_SITUACAO_CAND                           2
# DS_DETALHE_SITUACAO_CAND                    DEFERIDO
# TP_AGREMIACAO                              Coligação
# NR_PARTIDO                                        13
# SG_PARTIDO                                        PT
# NM_PARTIDO                 Partido dos Trabalhadores
# SQ_COLIGACAO                            280000050703
# NM_COLIGACAO                    O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO          PT / PC do B / PROS
# CD_SIT_TOT_TURNO                                   4
# DS_SIT_TOT_TURNO                          NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                N
# QT_VOTOS_NOMINAIS                                551
#
#                                                92421
# DT_GERACAO                                02/07/2019
# HH_GERACAO                                  19:46:18
# ANO_ELEICAO                                     2018
# CD_TIPO_ELEICAO                                    2
# NM_TIPO_ELEICAO                    Eleição Ordinária
# NR_TURNO                                           2
# CD_ELEICAO                                       296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018
# TP_ABRANGENCIA                                     F
# SG_UF                                             MA
# SG_UE                                             BR
# NM_UE                                         BRASIL
# CD_MUNICIPIO                                    9113
# NM_MUNICIPIO                SÃO DOMINGOS DO MARANHÃO
# NR_ZONA                                           60
# CD_CARGO                                           1
# DS_CARGO                                  Presidente
# SQ_CANDIDATO                            280000629808
# NR_CANDIDATO                                      13
# NM_CANDIDATO                         FERNANDO HADDAD
# NM_URNA_CANDIDATO                    FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                           #NULO#
# CD_SITUACAO_CANDIDATURA                           12
# DS_SITUACAO_CANDIDATURA                         APTO
# CD_DETALHE_SITUACAO_CAND                           2
# DS_DETALHE_SITUACAO_CAND                    DEFERIDO
# TP_AGREMIACAO                              Coligação
# NR_PARTIDO                                        13
# SG_PARTIDO                                        PT
# NM_PARTIDO                 Partido dos Trabalhadores
# SQ_COLIGACAO                            280000050703
# NM_COLIGACAO                    O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO          PT / PC do B / PROS
# CD_SIT_TOT_TURNO                                   4
# DS_SIT_TOT_TURNO                          NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                N
# QT_VOTOS_NOMINAIS                              13118

# %%
# Vamos verificar quantos municipios unicos existem no conjunto de dados
# Vamos pegar por codigo do municipio
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5741

# %%
# Mas o Brasil tem 5570 municipios
# Vamos verificar algumas cidades fora do Brasil
df_votacao[df_votacao['SG_UF'] == 'ZZ'].sample(4).T
# Out:
#                                                               88273  \
# DT_GERACAO                                               02/07/2019
# HH_GERACAO                                                 19:46:18
# ANO_ELEICAO                                                    2018
# CD_TIPO_ELEICAO                                                   2
# NM_TIPO_ELEICAO                                   Eleição Ordinária
# NR_TURNO                                                          2
# CD_ELEICAO                                                      296
# DS_ELEICAO                               ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                               28/10/2018
# TP_ABRANGENCIA                                                    F
# SG_UF                                                            ZZ
# SG_UE                                                            BR
# NM_UE                                                        BRASIL
# CD_MUNICIPIO                                                  29645
# NM_MUNICIPIO                                                   DÍLI
# NR_ZONA                                                           1
# CD_CARGO                                                          1
# DS_CARGO                                                 Presidente
# SQ_CANDIDATO                                           280000614517
# NR_CANDIDATO                                                     17
# NM_CANDIDATO                                 JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                    JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                          #NULO#
# CD_SITUACAO_CANDIDATURA                                          12
# DS_SITUACAO_CANDIDATURA                                        APTO
# CD_DETALHE_SITUACAO_CAND                                          2
# DS_DETALHE_SITUACAO_CAND                                   DEFERIDO
# TP_AGREMIACAO                                             Coligação
# NR_PARTIDO                                                       17
# SG_PARTIDO                                                      PSL
# NM_PARTIDO                                   Partido Social Liberal
# SQ_COLIGACAO                                           280000050386
# NM_COLIGACAO              BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                  PSL / PRTB
# CD_SIT_TOT_TURNO                                                  1
# DS_SIT_TOT_TURNO                                             ELEITO
# ST_VOTO_EM_TRANSITO                                               N
# QT_VOTOS_NOMINAIS                                                27
#
#                                                               17248  \
# DT_GERACAO                                               02/07/2019
# HH_GERACAO                                                 19:46:18
# ANO_ELEICAO                                                    2018
# CD_TIPO_ELEICAO                                                   2
# NM_TIPO_ELEICAO                                   Eleição Ordinária
# NR_TURNO                                                          2
# CD_ELEICAO                                                      296
# DS_ELEICAO                               ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                               28/10/2018
# TP_ABRANGENCIA                                                    F
# SG_UF                                                            ZZ
# SG_UE                                                            BR
# NM_UE                                                        BRASIL
# CD_MUNICIPIO                                                  39306
# NM_MUNICIPIO                                               ISTAMBUL
# NR_ZONA                                                           1
# CD_CARGO                                                          1
# DS_CARGO                                                 Presidente
# SQ_CANDIDATO                                           280000614517
# NR_CANDIDATO                                                     17
# NM_CANDIDATO                                 JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                    JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                          #NULO#
# CD_SITUACAO_CANDIDATURA                                          12
# DS_SITUACAO_CANDIDATURA                                        APTO
# CD_DETALHE_SITUACAO_CAND                                          2
# DS_DETALHE_SITUACAO_CAND                                   DEFERIDO
# TP_AGREMIACAO                                             Coligação
# NR_PARTIDO                                                       17
# SG_PARTIDO                                                      PSL
# NM_PARTIDO                                   Partido Social Liberal
# SQ_COLIGACAO                                           280000050386
# NM_COLIGACAO              BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                  PSL / PRTB
# CD_SIT_TOT_TURNO                                                  1
# DS_SIT_TOT_TURNO                                             ELEITO
# ST_VOTO_EM_TRANSITO                                               N
# QT_VOTOS_NOMINAIS                                                55
#
#                                                70402  \
# DT_GERACAO                                02/07/2019
# HH_GERACAO                                  19:46:18
# ANO_ELEICAO                                     2018
# CD_TIPO_ELEICAO                                    2
# NM_TIPO_ELEICAO                    Eleição Ordinária
# NR_TURNO                                           2
# CD_ELEICAO                                       296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018
# TP_ABRANGENCIA                                     F
# SG_UF                                             ZZ
# SG_UE                                             BR
# NM_UE                                         BRASIL
# CD_MUNICIPIO                                   99287
# NM_MUNICIPIO                                  LUSACA
# NR_ZONA                                            1
# CD_CARGO                                           1
# DS_CARGO                                  Presidente
# SQ_CANDIDATO                            280000629808
# NR_CANDIDATO                                      13
# NM_CANDIDATO                         FERNANDO HADDAD
# NM_URNA_CANDIDATO                    FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                           #NULO#
# CD_SITUACAO_CANDIDATURA                           12
# DS_SITUACAO_CANDIDATURA                         APTO
# CD_DETALHE_SITUACAO_CAND                           2
# DS_DETALHE_SITUACAO_CAND                    DEFERIDO
# TP_AGREMIACAO                              Coligação
# NR_PARTIDO                                        13
# SG_PARTIDO                                        PT
# NM_PARTIDO                 Partido dos Trabalhadores
# SQ_COLIGACAO                            280000050703
# NM_COLIGACAO                    O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO          PT / PC do B / PROS
# CD_SIT_TOT_TURNO                                   4
# DS_SIT_TOT_TURNO                          NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                N
# QT_VOTOS_NOMINAIS                                  2
#
#                                                11710
# DT_GERACAO                                02/07/2019
# HH_GERACAO                                  19:46:18
# ANO_ELEICAO                                     2018
# CD_TIPO_ELEICAO                                    2
# NM_TIPO_ELEICAO                    Eleição Ordinária
# NR_TURNO                                           2
# CD_ELEICAO                                       296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018
# TP_ABRANGENCIA                                     F
# SG_UF                                             ZZ
# SG_UE                                             BR
# NM_UE                                         BRASIL
# CD_MUNICIPIO                                   29319
# NM_MUNICIPIO                                 ARTIGAS
# NR_ZONA                                            1
# CD_CARGO                                           1
# DS_CARGO                                  Presidente
# SQ_CANDIDATO                            280000629808
# NR_CANDIDATO                                      13
# NM_CANDIDATO                         FERNANDO HADDAD
# NM_URNA_CANDIDATO                    FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                           #NULO#
# CD_SITUACAO_CANDIDATURA                           12
# DS_SITUACAO_CANDIDATURA                         APTO
# CD_DETALHE_SITUACAO_CAND                           2
# DS_DETALHE_SITUACAO_CAND                    DEFERIDO
# TP_AGREMIACAO                              Coligação
# NR_PARTIDO                                        13
# SG_PARTIDO                                        PT
# NM_PARTIDO                 Partido dos Trabalhadores
# SQ_COLIGACAO                            280000050703
# NM_COLIGACAO                    O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO          PT / PC do B / PROS
# CD_SIT_TOT_TURNO                                   4
# DS_SIT_TOT_TURNO                          NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                N
# QT_VOTOS_NOMINAIS                                 83

# %%
# Quantas cidades fora do Brasil estão no conjunto de dados?
df_votacao[df_votacao['SG_UF'] == 'ZZ']['CD_MUNICIPIO'].nunique()
# Out:
# 171

# %%
# Vamos eliminar os municpios de fora do Brasil
df_votacao = df_votacao[df_votacao['SG_UF'] != 'ZZ']

# %%
# Verificando a quantidade de municpios
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5570

# %%
# Os dados estão separados por municipio/zona
# Municipios pequenos normalmente tem apenas 1 zona eleitoral
# mas municipios maiores podem ter várias zonas eleitorias

# Vamos verificar Belo Horizonte
df_votacao[df_votacao['NM_MUNICIPIO'] == 'BELO HORIZONTE']
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 836    02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 3522   02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 7944   02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 15168  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 16589  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 22933  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 23911  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 35809  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 37145  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 37204  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 37403  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 37546  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 38747  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 39809  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 44712  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 45740  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 47179  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 49717  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 52146  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 53297  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 56955  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 58400  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 58406  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 61878  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 63200  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 63678  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 73450  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 74980  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 76583  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 78330  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 79870  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 84157  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 87361  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 91759  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 92229  02/07/2019   19:46:18         2018                2  Eleição Ordinária
# 93381  02/07/2019   19:46:18         2018                2  Eleição Ordinária
#
#        NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 836           2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 3522          2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 7944          2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 15168         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 16589         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 22933         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 23911         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 35809         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 37145         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 37204         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 37403         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 37546         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 38747         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 39809         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 44712         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 45740         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 47179         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 49717         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 52146         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 53297         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 56955         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 58400         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 58406         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 61878         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 63200         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 63678         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 73450         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 74980         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 76583         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 78330         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 79870         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 84157         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 87361         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 91759         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 92229         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 93381         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
#
#       TP_ABRANGENCIA  ... NR_PARTIDO SG_PARTIDO                 NM_PARTIDO  \
# 836                F  ...         13         PT  Partido dos Trabalhadores
# 3522               F  ...         17        PSL     Partido Social Liberal
# 7944               F  ...         13         PT  Partido dos Trabalhadores
# 15168              F  ...         17        PSL     Partido Social Liberal
# 16589              F  ...         13         PT  Partido dos Trabalhadores
# 22933              F  ...         17        PSL     Partido Social Liberal
# 23911              F  ...         13         PT  Partido dos Trabalhadores
# 35809              F  ...         17        PSL     Partido Social Liberal
# 37145              F  ...         13         PT  Partido dos Trabalhadores
# 37204              F  ...         17        PSL     Partido Social Liberal
# 37403              F  ...         17        PSL     Partido Social Liberal
# 37546              F  ...         13         PT  Partido dos Trabalhadores
# 38747              F  ...         13         PT  Partido dos Trabalhadores
# 39809              F  ...         13         PT  Partido dos Trabalhadores
# 44712              F  ...         13         PT  Partido dos Trabalhadores
# 45740              F  ...         17        PSL     Partido Social Liberal
# 47179              F  ...         17        PSL     Partido Social Liberal
# 49717              F  ...         17        PSL     Partido Social Liberal
# 52146              F  ...         17        PSL     Partido Social Liberal
# 53297              F  ...         17        PSL     Partido Social Liberal
# 56955              F  ...         13         PT  Partido dos Trabalhadores
# 58400              F  ...         17        PSL     Partido Social Liberal
# 58406              F  ...         13         PT  Partido dos Trabalhadores
# 61878              F  ...         17        PSL     Partido Social Liberal
# 63200              F  ...         17        PSL     Partido Social Liberal
# 63678              F  ...         13         PT  Partido dos Trabalhadores
# 73450              F  ...         13         PT  Partido dos Trabalhadores
# 74980              F  ...         13         PT  Partido dos Trabalhadores
# 76583              F  ...         17        PSL     Partido Social Liberal
# 78330              F  ...         13         PT  Partido dos Trabalhadores
# 79870              F  ...         13         PT  Partido dos Trabalhadores
# 84157              F  ...         13         PT  Partido dos Trabalhadores
# 87361              F  ...         17        PSL     Partido Social Liberal
# 91759              F  ...         17        PSL     Partido Social Liberal
# 92229              F  ...         17        PSL     Partido Social Liberal
# 93381              F  ...         13         PT  Partido dos Trabalhadores
#
#        SQ_COLIGACAO                               NM_COLIGACAO  \
# 836    280000050703                       O POVO FELIZ DE NOVO
# 3522   280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 7944   280000050703                       O POVO FELIZ DE NOVO
# 15168  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 16589  280000050703                       O POVO FELIZ DE NOVO
# 22933  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 23911  280000050703                       O POVO FELIZ DE NOVO
# 35809  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 37145  280000050703                       O POVO FELIZ DE NOVO
# 37204  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 37403  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 37546  280000050703                       O POVO FELIZ DE NOVO
# 38747  280000050703                       O POVO FELIZ DE NOVO
# 39809  280000050703                       O POVO FELIZ DE NOVO
# 44712  280000050703                       O POVO FELIZ DE NOVO
# 45740  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 47179  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 49717  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 52146  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 53297  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 56955  280000050703                       O POVO FELIZ DE NOVO
# 58400  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 58406  280000050703                       O POVO FELIZ DE NOVO
# 61878  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 63200  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 63678  280000050703                       O POVO FELIZ DE NOVO
# 73450  280000050703                       O POVO FELIZ DE NOVO
# 74980  280000050703                       O POVO FELIZ DE NOVO
# 76583  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 78330  280000050703                       O POVO FELIZ DE NOVO
# 79870  280000050703                       O POVO FELIZ DE NOVO
# 84157  280000050703                       O POVO FELIZ DE NOVO
# 87361  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 91759  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 92229  280000050386  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 93381  280000050703                       O POVO FELIZ DE NOVO
#
#        DS_COMPOSICAO_COLIGACAO  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO  \
# 836        PT / PC do B / PROS                 4       NÃO ELEITO
# 3522                PSL / PRTB                 1           ELEITO
# 7944       PT / PC do B / PROS                 4       NÃO ELEITO
# 15168               PSL / PRTB                 1           ELEITO
# 16589      PT / PC do B / PROS                 4       NÃO ELEITO
# 22933               PSL / PRTB                 1           ELEITO
# 23911      PT / PC do B / PROS                 4       NÃO ELEITO
# 35809               PSL / PRTB                 1           ELEITO
# 37145      PT / PC do B / PROS                 4       NÃO ELEITO
# 37204               PSL / PRTB                 1           ELEITO
# 37403               PSL / PRTB                 1           ELEITO
# 37546      PT / PC do B / PROS                 4       NÃO ELEITO
# 38747      PT / PC do B / PROS                 4       NÃO ELEITO
# 39809      PT / PC do B / PROS                 4       NÃO ELEITO
# 44712      PT / PC do B / PROS                 4       NÃO ELEITO
# 45740               PSL / PRTB                 1           ELEITO
# 47179               PSL / PRTB                 1           ELEITO
# 49717               PSL / PRTB                 1           ELEITO
# 52146               PSL / PRTB                 1           ELEITO
# 53297               PSL / PRTB                 1           ELEITO
# 56955      PT / PC do B / PROS                 4       NÃO ELEITO
# 58400               PSL / PRTB                 1           ELEITO
# 58406      PT / PC do B / PROS                 4       NÃO ELEITO
# 61878               PSL / PRTB                 1           ELEITO
# 63200               PSL / PRTB                 1           ELEITO
# 63678      PT / PC do B / PROS                 4       NÃO ELEITO
# 73450      PT / PC do B / PROS                 4       NÃO ELEITO
# 74980      PT / PC do B / PROS                 4       NÃO ELEITO
# 76583               PSL / PRTB                 1           ELEITO
# 78330      PT / PC do B / PROS                 4       NÃO ELEITO
# 79870      PT / PC do B / PROS                 4       NÃO ELEITO
# 84157      PT / PC do B / PROS                 4       NÃO ELEITO
# 87361               PSL / PRTB                 1           ELEITO
# 91759               PSL / PRTB                 1           ELEITO
# 92229               PSL / PRTB                 1           ELEITO
# 93381      PT / PC do B / PROS                 4       NÃO ELEITO
#
#        ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS
# 836                      N              24736
# 3522                     N              44233
# 7944                     N              23077
# 15168                    N              44730
# 16589                    N              22870
# 22933                    N              59381
# 23911                    N              25851
# 35809                    N              45172
# 37145                    N              21109
# 37204                    N              49051
# 37403                    N              51400
# 37546                    N              24997
# 38747                    N              27865
# 39809                    N              25765
# 44712                    N              23991
# 45740                    N              43886
# 47179                    N              48169
# 49717                    N              49869
# 52146                    N              57575
# 53297                    N              47923
# 56955                    N              27022
# 58400                    N              45309
# 58406                    N              31938
# 61878                    N              63139
# 63200                    N              44471
# 63678                    N              33475
# 73450                    N              28730
# 74980                    N              28386
# 76583                    N              56272
# 78330                    N              25463
# 79870                    N              26211
# 84157                    N              28923
# 87361                    N              46683
# 91759                    N              55333
# 92229                    N              48917
# 93381                    N              22478
#
# [36 rows x 38 columns]

# %%
# Eliminar algumas colunas do dataframe que não serão utilizadas
df_votacao = df_votacao[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO',
                        'NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]

df_votacao.head()
# Out:
#    SG_UF  CD_MUNICIPIO       NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10    RN         16306             JUNDIÁ            17    JAIR BOLSONARO
# 12    PB         20575    JUNCO DO SERIDÓ            17    JAIR BOLSONARO
# 14    RS         88013       PORTO ALEGRE            17    JAIR BOLSONARO
# 15    RS         88064        VALE DO SOL            17    JAIR BOLSONARO
# 16    MG         51659  SANTANA DA VARGEM            17    JAIR BOLSONARO
#
#     QT_VOTOS_NOMINAIS
# 10                864
# 12                849
# 14              37665
# 15               3425
# 16               2312

# %%
# Precisamos agregar os dados por municipio e candidato
df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum()
# Out:
#                                                                           QT_VOTOS_NOMINAIS
# SG_UF CD_MUNICIPIO NM_MUNICIPIO           NR_CANDIDATO NM_URNA_CANDIDATO
# AC    1007         BUJARI                 13           FERNANDO HADDAD                 1274
#                                           17           JAIR BOLSONARO                  4676
#       1015         CAPIXABA               13           FERNANDO HADDAD                 1086
#                                           17           JAIR BOLSONARO                  3895
#       1023         PORTO ACRE             13           FERNANDO HADDAD                 2059
#                                           17           JAIR BOLSONARO                  7150
#       1031         SANTA ROSA DO PURUS    13           FERNANDO HADDAD                  975
#                                           17           JAIR BOLSONARO                   847
#       1040         MARECHAL THAUMATURGO   13           FERNANDO HADDAD                 2451
#                                           17           JAIR BOLSONARO                  2548
#       1058         BRASILÉIA              13           FERNANDO HADDAD                 3208
#                                           17           JAIR BOLSONARO                  8711
#       1066         PORTO WALTER           13           FERNANDO HADDAD                 1208
#                                           17           JAIR BOLSONARO                  1897
#       1074         CRUZEIRO DO SUL        13           FERNANDO HADDAD                 7818
#                                           17           JAIR BOLSONARO                 31147
#       1082         RODRIGUES ALVES        13           FERNANDO HADDAD                 1682
#                                           17           JAIR BOLSONARO                  4762
#       1090         MÂNCIO LIMA            13           FERNANDO HADDAD                 2334
#                                           17           JAIR BOLSONARO                  5225
#       1104         JORDÃO                 13           FERNANDO HADDAD                 1415
#                                           17           JAIR BOLSONARO                  1375
#       1112         EPITACIOLÂNDIA         13           FERNANDO HADDAD                 2026
#                                           17           JAIR BOLSONARO                  6284
#       1120         ACRELÂNDIA             13           FERNANDO HADDAD                 1300
#                                           17           JAIR BOLSONARO                  5165
#       1139         FEIJÓ                  13           FERNANDO HADDAD                 5256
#                                           17           JAIR BOLSONARO                  6296
#       1392         RIO BRANCO             13           FERNANDO HADDAD                32937
#                                           17           JAIR BOLSONARO                158264
# ...                                                                                     ...
# TO    96210        TOCANTINÓPOLIS         13           FERNANDO HADDAD                 7512
#                                           17           JAIR BOLSONARO                  3592
#       96270        GUARAÍ                 13           FERNANDO HADDAD                 4965
#                                           17           JAIR BOLSONARO                  6544
#       96296        PRESIDENTE KENNEDY     13           FERNANDO HADDAD                  919
#                                           17           JAIR BOLSONARO                   849
#       96431        XAMBIOÁ                13           FERNANDO HADDAD                 2888
#                                           17           JAIR BOLSONARO                  2939
#       96490        PALMEIRÓPOLIS          13           FERNANDO HADDAD                 1658
#                                           17           JAIR BOLSONARO                  2089
#       96598        SILVANÓPOLIS           13           FERNANDO HADDAD                 1793
#                                           17           JAIR BOLSONARO                  1192
#       96636        NOVA OLINDA            13           FERNANDO HADDAD                 3277
#                                           17           JAIR BOLSONARO                  2443
#       96652        WANDERLÂNDIA           13           FERNANDO HADDAD                 2735
#                                           17           JAIR BOLSONARO                  1944
#       96679        FIGUEIRÓPOLIS          13           FERNANDO HADDAD                 1418
#                                           17           JAIR BOLSONARO                  1433
#       96792        RIO SONO               13           FERNANDO HADDAD                 1616
#                                           17           JAIR BOLSONARO                   959
#       96830        FÁTIMA                 13           FERNANDO HADDAD                  946
#                                           17           JAIR BOLSONARO                  1092
#       96857        AUGUSTINÓPOLIS         13           FERNANDO HADDAD                 5598
#                                           17           JAIR BOLSONARO                  3171
#       96954        ALIANÇA DO TOCANTINS   13           FERNANDO HADDAD                 1449
#                                           17           JAIR BOLSONARO                  1215
#       96970        APARECIDA DO RIO NEGRO 13           FERNANDO HADDAD                 1291
#                                           17           JAIR BOLSONARO                  1171
#       96997        BARROLÂNDIA            13           FERNANDO HADDAD                 1545
#                                           17           JAIR BOLSONARO                  1501
#
# [11140 rows x 1 columns]

# %%
# Fazer o groupby, reindexar o indice, vai salvar isso em um dataframe
df_votacao = df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum().reset_index()

df_votacao.sample(4)
# Out:
#      SG_UF  CD_MUNICIPIO      NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 2023    GO         93831  GUARANI DE GOIÁS            17    JAIR BOLSONARO
# 8954    SC         80616          CAMBORIÚ            13   FERNANDO HADDAD
# 3936    MG         49875    PEDRO TEIXEIRA            13   FERNANDO HADDAD
# 446     BA         33030             ABARÉ            13   FERNANDO HADDAD
#
#       QT_VOTOS_NOMINAIS
# 2023                946
# 8954               8233
# 3936               1188
# 446                7453

# %%
# Vamos verificar novamente a cidade de Belo Horizonte
df_votacao[df_votacao['NM_MUNICIPIO'] == 'BELO HORIZONTE']
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 2936    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 2937    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
#
#       QT_VOTOS_NOMINAIS
# 2936             472887
# 2937             901513

# %%
# Ordenar o dataframe pela quantidade de votos e depois deixar apenas o primeiro
# registro de cada municipio
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False).head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 10722    SP         71072       SÃO PAULO            13   FERNANDO HADDAD
# 7369     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 7368     RJ         60011  RIO DE JANEIRO            13   FERNANDO HADDAD
# 1607     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 2937     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 309      AM          2550          MANAUS            17    JAIR BOLSONARO
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 10722            2424125
# 7369             2179896
# 7368             1105393
# 1607             1080411
# 1054              985532
# 2937              901513
# 6659              786377
# 1376              739265
# 309               686999

# %%
# Vamos ordenar
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False, inplace=True)

# dropar as linhas duplicadas, mantendo a primeira
df_votacao.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)

df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 7369     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 1607     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 2937     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 309      AM          2550          MANAUS            17    JAIR BOLSONARO
# 2013     GO         93734         GOIÂNIA            17    JAIR BOLSONARO
# 5834     PE         25313          RECIFE            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 7369             2179896
# 1607             1080411
# 1054              985532
# 2937              901513
# 6659              786377
# 1376              739265
# 309               686999
# 2013              528525
# 5834              482673

# %%
# Vamos verificar novamente a cidade de Belo Horizonte
df_votacao[df_votacao['NM_MUNICIPIO'] == 'BELO HORIZONTE']
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 2937    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
#
#       QT_VOTOS_NOMINAIS
# 2937             901513

# %%
# Agora vamos criar uma coluna representando o resultado da eleição naquele municipio
# sendo que o Resultado é True se o candidato Bolsonaro venceu naquele municipio
# e False em caso contrário
df_votacao['RESULTADO'] = df_votacao['NR_CANDIDATO'].apply(lambda x: x == 17)

# %%
# Verificando o resultado
df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 7369     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 1607     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 2937     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 309      AM          2550          MANAUS            17    JAIR BOLSONARO
# 2013     GO         93734         GOIÂNIA            17    JAIR BOLSONARO
# 5834     PE         25313          RECIFE            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS  RESULTADO
# 10723            3694834       True
# 7369             2179896       True
# 1607             1080411       True
# 1054              985532      False
# 2937              901513       True
# 6659              786377       True
# 1376              739265      False
# 309               686999       True
# 2013              528525       True
# 5834              482673      False

# %%
# Mostrando alguns valores do dataframe do geopandas
df_mapa.sample(3)
# Out:
#      NM_MUNICIP CD_GEOCMU                                           geometry
# 1410    SABARÃ   3156700  POLYGON ((-43.70842700000004 -19.7466019966005...
# 2194   POMPÃIA   3540002  POLYGON ((-50.06033275900001 -21.8744557116529...
# 1270   NOVA ERA   3144706  POLYGON ((-42.90841700000001 -19.7497339966007...

# %%
# tentando encontrar o municipio pelo código
df_votacao[df_votacao['CD_MUNICIPIO'] == 3156700]
# Out:
# Empty DataFrame
# Columns: [SG_UF, CD_MUNICIPIO, NM_MUNICIPIO, NR_CANDIDATO, NM_URNA_CANDIDATO, QT_VOTOS_NOMINAIS, RESULTADO]
# Index: []

# %%
# Porque não podemos usar o nome do municipio para juntar
df_votacao[df_votacao['NM_MUNICIPIO'] == 'OURO BRANCO']
# Out:
#      SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 3867    MG         49174  OURO BRANCO            17    JAIR BOLSONARO
# 174     AL         28215  OURO BRANCO            13   FERNANDO HADDAD
# 7570    RN         17698  OURO BRANCO            13   FERNANDO HADDAD
#
#       QT_VOTOS_NOMINAIS  RESULTADO
# 3867              12198       True
# 174                5156      False
# 7570               2463      False

# %%
# Recuperar a tabela de correspondencia entre IBGE e TSE
# direto do github do Estadão
link = 'https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv'

df_equivalencia = pd.read_csv(link)

df_equivalencia.head()
# Out:
#              chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0    ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1  ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 2     ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 3        ac bujari        BUJARI  AC      1200138     1007    NaN
# 4      ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
# Vamos preparar os dataframes

# %%
# Vamos reindexar o dataframe de votação pelo código do TSE
df_vot_novo = df_votacao.copy()

df_vot_novo.set_index('CD_MUNICIPIO', drop=False, inplace=True)

df_vot_novo.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO            17
# 60011           RJ         60011  RIO DE JANEIRO            17
# 97012           DF         97012        BRASÍLIA            17
# 38490           BA         38490        SALVADOR            13
# 41238           MG         41238  BELO HORIZONTE            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO
# 71072           JAIR BOLSONARO            3694834       True
# 60011           JAIR BOLSONARO            2179896       True
# 97012           JAIR BOLSONARO            1080411       True
# 38490          FERNANDO HADDAD             985532      False
# 41238           JAIR BOLSONARO             901513       True

# %%
# Vamos reindexar o dataframe de Equivalencia pelo Código do TSE
df_equi_novo = df_equivalencia.copy()

df_equi_novo.set_index('COD_TSE', drop=False, inplace=True)

df_equi_novo.head()
# Out:
#                    chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# COD_TSE
# 1120       ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1570     ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 1058        ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 1007           ac bujari        BUJARI  AC      1200138     1007    NaN
# 1015         ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
# Verificando o tamanho dos dataframes
df_vot_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 7 columns):
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null int64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null int64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null int64
# RESULTADO            5570 non-null bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 310.0+ KB

# %%
df_equi_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 1120 to 96431
# Data columns (total 6 columns):
# chave          5570 non-null object
# NOME           5570 non-null object
# UF             5570 non-null object
# GEOCOD_IBGE    5570 non-null int64
# COD_TSE        5570 non-null int64
# AJUSTE         29 non-null object
# dtypes: int64(2), object(4)
# memory usage: 304.6+ KB

# %%
# Criando um novo dataframe com base no merge de Votação e Equivalencia
df_vot_equi = df_vot_novo.join(df_equi_novo)

df_vot_equi.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO            17
# 60011           RJ         60011  RIO DE JANEIRO            17
# 97012           DF         97012        BRASÍLIA            17
# 38490           BA         38490        SALVADOR            13
# 41238           MG         41238  BELO HORIZONTE            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO  \
# CD_MUNICIPIO
# 71072           JAIR BOLSONARO            3694834       True
# 60011           JAIR BOLSONARO            2179896       True
# 97012           JAIR BOLSONARO            1080411       True
# 38490          FERNANDO HADDAD             985532      False
# 41238           JAIR BOLSONARO             901513       True
#
#                           chave            NOME  UF  GEOCOD_IBGE  COD_TSE  \
# CD_MUNICIPIO
# 71072              sp sao paulo       SÃO PAULO  SP      3550308    71072
# 60011         rj rio de janeiro  RIO DE JANEIRO  RJ      3304557    60011
# 97012               df brasilia        BRASÍLIA  DF      5300108    97012
# 38490               ba salvador        SALVADOR  BA      2927408    38490
# 41238         mg belo horizonte  BELO HORIZONTE  MG      3106200    41238
#
#              AJUSTE
# CD_MUNICIPIO
# 71072           NaN
# 60011           NaN
# 97012           NaN
# 38490           NaN
# 41238           NaN

# %%
# Vamos juntar o dataframe do GeoPandas com o dataframe Votação/Equivalência

# %%
df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null int64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null int64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null int64
# RESULTADO            5570 non-null bool
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null int64
# COD_TSE              5570 non-null int64
# AJUSTE               29 non-null object
# dtypes: bool(1), int64(5), object(7)
# memory usage: 731.1+ KB

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
# NM_MUNICIP    5572 non-null object
# CD_GEOCMU     5572 non-null object
# geometry      5572 non-null object
# dtypes: object(3)
# memory usage: 130.7+ KB

# %%
# Transformar a coluna de codigo de IBGE do dataframe de Votação/Equivalência
df_vot_equi['GEOCOD_IBGE'] = df_vot_equi['GEOCOD_IBGE'].astype(str)

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null int64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null int64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null int64
# RESULTADO            5570 non-null bool
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null object
# COD_TSE              5570 non-null int64
# AJUSTE               29 non-null object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 731.1+ KB

# %%
# Vamos unificar os indices

# Mudando o indice do dataframe de Mapa
df_mapa.set_index('CD_GEOCMU', drop=False, inplace=True)

# %%
# Mudando o indice do dataframe de Votação/Equivalência
df_vot_equi.set_index('GEOCOD_IBGE', drop=False, inplace=True)

# %%
# Vamos juntar os dataframes
df_mapa_novo = df_mapa.join(df_vot_equi)

df_mapa_novo.head().T
# Out:
# CD_GEOCMU                                                    3509106  \
# NM_MUNICIP                                                    CAIUÃ
# CD_GEOCMU                                                    3509106
# geometry           POLYGON ((-51.86001052999998 -21.5807199056459...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   62839
# NM_MUNICIPIO                                                   CAIUÁ
# NR_CANDIDATO                                                      13
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                               1320
# RESULTADO                                                      False
# chave                                                       sp caiua
# NOME                                                           CAIUÁ
# UF                                                                SP
# GEOCOD_IBGE                                                  3509106
# COD_TSE                                                        62839
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3511003  \
# NM_MUNICIP                                                  CASTILHO
# CD_GEOCMU                                                    3511003
# geometry           POLYGON ((-51.41936432700003 -20.6810765586240...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   63215
# NM_MUNICIPIO                                                CASTILHO
# NR_CANDIDATO                                                      17
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# QT_VOTOS_NOMINAIS                                               5005
# RESULTADO                                                       True
# chave                                                    sp castilho
# NOME                                                        CASTILHO
# UF                                                                SP
# GEOCOD_IBGE                                                  3511003
# COD_TSE                                                        63215
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3514403  \
# NM_MUNICIP                                                   DRACENA
# CD_GEOCMU                                                    3514403
# geometry           POLYGON ((-51.48515406800003 -21.4276462056422...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   63894
# NM_MUNICIPIO                                                 DRACENA
# NR_CANDIDATO                                                      17
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# QT_VOTOS_NOMINAIS                                              19141
# RESULTADO                                                       True
# chave                                                     sp dracena
# NOME                                                         DRACENA
# UF                                                                SP
# GEOCOD_IBGE                                                  3514403
# COD_TSE                                                        63894
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3515301  \
# NM_MUNICIP                                          ESTRELA DO NORTE
# CD_GEOCMU                                                    3515301
# geometry           POLYGON ((-51.57097467399996 -22.3988718766653...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   64076
# NM_MUNICIPIO                                        ESTRELA DO NORTE
# NR_CANDIDATO                                                      17
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# QT_VOTOS_NOMINAIS                                                875
# RESULTADO                                                       True
# chave                                            sp estrela do norte
# NOME                                                ESTRELA DO NORTE
# UF                                                                SP
# GEOCOD_IBGE                                                  3515301
# COD_TSE                                                        64076
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3515350
# NM_MUNICIP                                EUCLIDES DA CUNHA PAULISTA
# CD_GEOCMU                                                    3515350
# geometry           POLYGON ((-52.44569233499996 -22.6082794076701...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   61000
# NM_MUNICIPIO                              EUCLIDES DA CUNHA PAULISTA
# NR_CANDIDATO                                                      13
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                               2860
# RESULTADO                                                      False
# chave                                  sp euclides da cunha paulista
# NOME                                      EUCLIDES DA CUNHA PAULISTA
# UF                                                                SP
# GEOCOD_IBGE                                                  3515350
# COD_TSE                                                        61000
# AJUSTE                                                           NaN

# %%
# Verificando o tamanho do mapa novo
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 3509106 to 1101807
# Data columns (total 16 columns):
# NM_MUNICIP           5572 non-null object
# CD_GEOCMU            5572 non-null object
# geometry             5572 non-null object
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null float64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null float64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null float64
# RESULTADO            5570 non-null object
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null object
# COD_TSE              5570 non-null float64
# AJUSTE               29 non-null object
# dtypes: float64(4), object(12)
# memory usage: 900.0+ KB

# %%
# Vamos descobrir os 2 municipios a mais no mapa
df_mapa_novo[df_mapa_novo['NR_CANDIDATO'].isnull()]
# Out:
#                 NM_MUNICIP CD_GEOCMU  \
# CD_GEOCMU
# 4300001        LAGOA MIRIM   4300001
# 4300002    LAGOA DOS PATOS   4300002
#
#                                                     geometry SG_UF  \
# CD_GEOCMU
# 4300001    POLYGON ((-52.6224061101419 -32.14661509114978...   NaN
# 4300002    POLYGON ((-51.29028281599994 -30.0022243238175...   NaN
#
#            CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# CD_GEOCMU
# 4300001             NaN          NaN           NaN               NaN
# 4300002             NaN          NaN           NaN               NaN
#
#            QT_VOTOS_NOMINAIS RESULTADO chave NOME   UF GEOCOD_IBGE  COD_TSE  \
# CD_GEOCMU
# 4300001                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300002                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
#
#           AJUSTE
# CD_GEOCMU
# 4300001      NaN
# 4300002      NaN

# %%
# Matar a coluna ajuste
df_mapa_novo.drop(columns=['AJUSTE'], inplace=True)

# %%
# Vamos eliminar a informação das duas lagoas do RS
df_mapa_novo.dropna(inplace=True)

# %%
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5570 entries, 3509106 to 1101807
# Data columns (total 15 columns):
# NM_MUNICIP           5570 non-null object
# CD_GEOCMU            5570 non-null object
# geometry             5570 non-null object
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null float64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null float64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null float64
# RESULTADO            5570 non-null object
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null object
# COD_TSE              5570 non-null float64
# dtypes: float64(4), object(11)
# memory usage: 696.2+ KB

# %%
# Vamos desenhar o mapa

# Criar a referência para o código de cor (False/0 = red, True/1 = green)
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['red', 'green'])

# Desenhando o mapa
fig, ax = plt.subplots(1, figsize=(12, 12))

ax = df_mapa_novo.plot(column='RESULTADO', cmap=cmap, legend=True, linewidth=0.1, ax=ax,
                      edgecolor='grey')

# Escondendo o eixos
ax.set_axis_off()

# Colocando um título
ax.set_title('Resultado Eleição 2018 por Município / 2º Turno', fontdict={'fontsize': '25', 'fontweight': '3'})

# Criando uma nota do rodapé
ax.annotate('Fonte: IBGE, 2015; TSE, 2019; Jornal o Estado de São Paulo, 2019',
    xy=(0.1, 0.08), xycoords='figure fraction', horizontalalignment='left',
    verticalalignment='top', fontsize=10, color='#555555')

# Alterando a legenda
leg = ax.get_legend()
leg.get_texts()[0].set_text('Fernando Haddad')
leg.get_texts()[1].set_text('Jair Bolsonaro')

plt.show()
