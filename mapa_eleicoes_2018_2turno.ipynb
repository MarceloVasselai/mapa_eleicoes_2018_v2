# %% [markdown]
# # Mapa do resultado do 2º Turno das Eleições Presidencias de 2018 por Município

# %%
# Importando as bibliotecas
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Caminho para o arquivo Shapefile 
caminho_shapefile = r'D:\Usuários\Downloads\br_municipios\BRMUE250GC_SIR.shp'

# Ler o Shapefile
df_mapa = gpd.read_file(caminho_shapefile)

# Exibir as primeiras linhas
df_mapa.head()
# Out:
#               NM_MUNICIP CD_GEOCMU  \
# 0     CACHOEIRA DO PIRIÁ   1501956
# 1  SÃO JOSÉ DOS BASÍLIOS   2111250
# 2  APARECIDA DO RIO DOCE   5201454
# 3             ARENÓPOLIS   5202353
# 4                  CURUÁ   1502855
#
#                                             geometry
# 0  POLYGON ((-46.31955 -1.75518, -46.3199 -1.7557...
# 1  POLYGON ((-44.63409 -5.03498, -44.63407 -5.034...
# 2  POLYGON ((-51.1423 -18.29672, -51.14236 -18.29...
# 3  POLYGON ((-51.69953 -16.2327, -51.69957 -16.23...
# 4  POLYGON ((-55.17193 -1.83331, -55.16647 -1.731...

# %%
# Verificando tamanho e colunas
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NM_MUNICIP  5572 non-null   object
#  1   CD_GEOCMU   5572 non-null   object
#  2   geometry    5572 non-null   geometry
# dtypes: geometry(1), object(2)
# memory usage: 130.7+ KB

# %%
# Vamos exibir o mapa (plotar o shapefile)
df_mapa.plot()
# Out:
# <Axes: >

# %%
# Vamos expandir o espaço para desenhar o mapa
fig, ax = plt.subplots(1, figsize=(12,12))

# desenhar o mapa
df_mapa.plot(ax=ax)

# tirar os eixos
ax.set_axis_off()

plt.show()

# %%
# Vamos carregar o arquivo com o resultado da eleição no Brasil dividido por municipio/zona
df_votacao = pd.read_csv(r'D:\Usuários\Downloads\votacao_candidato_munzona_2018_BRASIL.csv',
                        sep=';', encoding='latin1')

df_votacao.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 1  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 2  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 3  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 4  13/11/2024   10:56:11         2018                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 1         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 2         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 3         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 4         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
#
#   TP_ABRANGENCIA  ... DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 1              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 2              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 3              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 4              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
#
#    DS_COMPOSICAO_COLIGACAO ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  \
# 0            SOLIDARIEDADE                   N                 67
# 1            SOLIDARIEDADE                   N                 15
# 2            SOLIDARIEDADE                   N                215
# 3            SOLIDARIEDADE                   N                 12
# 4            SOLIDARIEDADE                   N                  6
#
#    NM_TIPO_DESTINACAO_VOTOS QT_VOTOS_NOMINAIS_VALIDOS  CD_SIT_TOT_TURNO  \
# 0                    Válido                        67                 3
# 1                    Válido                        15                 3
# 2                    Válido                       215                 3
# 3                    Válido                        12                 3
# 4                    Válido                         6                 3
#
#    DS_SIT_TOT_TURNO
# 0  ELEITO POR MÉDIA
# 1  ELEITO POR MÉDIA
# 2  ELEITO POR MÉDIA
# 3  ELEITO POR MÉDIA
# 4  ELEITO POR MÉDIA
#
# [5 rows x 50 columns]

# %%
# Visualizando o dataframe transposto
df_votacao.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 1  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 2  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 3  13/11/2024   10:56:11         2018                2  Eleição Ordinária
# 4  13/11/2024   10:56:11         2018                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 1         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 2         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 3         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
# 4         1         297  ELEIÇÕES GERAIS ESTADUAIS 2018  07/10/2018
#
#   TP_ABRANGENCIA  ... DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 1              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 2              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 3              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
# 4              E  ...                  #NULO#  250000050143  PARTIDO ISOLADO
#
#    DS_COMPOSICAO_COLIGACAO ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  \
# 0            SOLIDARIEDADE                   N                 67
# 1            SOLIDARIEDADE                   N                 15
# 2            SOLIDARIEDADE                   N                215
# 3            SOLIDARIEDADE                   N                 12
# 4            SOLIDARIEDADE                   N                  6
#
#    NM_TIPO_DESTINACAO_VOTOS QT_VOTOS_NOMINAIS_VALIDOS  CD_SIT_TOT_TURNO  \
# 0                    Válido                        67                 3
# 1                    Válido                        15                 3
# 2                    Válido                       215                 3
# 3                    Válido                        12                 3
# 4                    Válido                         6                 3
#
#    DS_SIT_TOT_TURNO
# 0  ELEITO POR MÉDIA
# 1  ELEITO POR MÉDIA
# 2  ELEITO POR MÉDIA
# 3  ELEITO POR MÉDIA
# 4  ELEITO POR MÉDIA
#
# [5 rows x 50 columns]

# %%
# Separar os dados pois precisamos apenas dos dados de 2 Turno
df_votacao = df_votacao[df_votacao['NR_TURNO'] == 2]

df_votacao.sample(3).T
# Out:
#                                                                      8076470  \
# DT_GERACAO                                                        13/11/2024
# HH_GERACAO                                                          10:56:11
# ANO_ELEICAO                                                             2018
# CD_TIPO_ELEICAO                                                            2
# NM_TIPO_ELEICAO                                            Eleição Ordinária
# NR_TURNO                                                                   2
# CD_ELEICAO                                                               298
# DS_ELEICAO                                    ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                                        28/10/2018
# TP_ABRANGENCIA                                                             E
# SG_UF                                                                     AM
# SG_UE                                                                     AM
# NM_UE                                                               AMAZONAS
# CD_MUNICIPIO                                                            2291
# NM_MUNICIPIO                                                        EIRUNEPÉ
# NR_ZONA                                                                   11
# CD_CARGO                                                                   3
# DS_CARGO                                                          Governador
# SQ_CANDIDATO                                                     40000610067
# NR_CANDIDATO                                                              12
# NM_CANDIDATO                                        AMAZONINO ARMANDO MENDES
# NM_URNA_CANDIDATO                                           AMAZONINO MENDES
# NM_SOCIAL_CANDIDATO                                                   #NULO#
# CD_SITUACAO_CANDIDATURA                                                   12
# DS_SITUACAO_CANDIDATURA                                                 APTO
# CD_DETALHE_SITUACAO_CAND                                                   2
# DS_DETALHE_SITUACAO_CAND                                            DEFERIDO
# CD_SITUACAO_JULGAMENTO                                                    -3
# DS_SITUACAO_JULGAMENTO                                                   #NE
# CD_SITUACAO_CASSACAO                                                      -3
# DS_SITUACAO_CASSACAO                                                     #NE
# CD_SITUACAO_DIPLOMA                                                       -3
# DS_SITUACAO_DIPLOMA                                                      #NE
# TP_AGREMIACAO                                                      COLIGAÇÃO
# NR_PARTIDO                                                                12
# SG_PARTIDO                                                               PDT
# NM_PARTIDO                                   Partido Democrático Trabalhista
# NR_FEDERACAO                                                              -1
# NM_FEDERACAO                                                          #NULO#
# SG_FEDERACAO                                                          #NULO#
# DS_COMPOSICAO_FEDERACAO                                               #NULO#
# SQ_COLIGACAO                                                     40000050267
# NM_COLIGACAO                                             EU VOTO NO AMAZONAS
# DS_COMPOSICAO_COLIGACAO    PDT / PRP / AVANTE / PP / PV / PR / SOLIDARIED...
# ST_VOTO_EM_TRANSITO                                                        N
# QT_VOTOS_NOMINAIS                                                       7278
# NM_TIPO_DESTINACAO_VOTOS                                              Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                               7278
# CD_SIT_TOT_TURNO                                                           4
# DS_SIT_TOT_TURNO                                                  NÃO ELEITO
#
#                                                              7889162  \
# DT_GERACAO                                                13/11/2024
# HH_GERACAO                                                  10:56:11
# ANO_ELEICAO                                                     2018
# CD_TIPO_ELEICAO                                                    2
# NM_TIPO_ELEICAO                                    Eleição Ordinária
# NR_TURNO                                                           2
# CD_ELEICAO                                                       296
# DS_ELEICAO                                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                                28/10/2018
# TP_ABRANGENCIA                                                     F
# SG_UF                                                             PR
# SG_UE                                                             BR
# NM_UE                                                         BRASIL
# CD_MUNICIPIO                                                   74977
# NM_MUNICIPIO                                              CATANDUVAS
# NR_ZONA                                                          166
# CD_CARGO                                                           1
# DS_CARGO                                                  Presidente
# SQ_CANDIDATO                                            280000614517
# NR_CANDIDATO                                                      17
# NM_CANDIDATO                                  JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                           #NULO#
# CD_SITUACAO_CANDIDATURA                                           12
# DS_SITUACAO_CANDIDATURA                                         APTO
# CD_DETALHE_SITUACAO_CAND                                           2
# DS_DETALHE_SITUACAO_CAND                                    DEFERIDO
# CD_SITUACAO_JULGAMENTO                                            -3
# DS_SITUACAO_JULGAMENTO                                           #NE
# CD_SITUACAO_CASSACAO                                              -3
# DS_SITUACAO_CASSACAO                                             #NE
# CD_SITUACAO_DIPLOMA                                               -3
# DS_SITUACAO_DIPLOMA                                              #NE
# TP_AGREMIACAO                                              COLIGAÇÃO
# NR_PARTIDO                                                        17
# SG_PARTIDO                                                       PSL
# NM_PARTIDO                                    Partido Social Liberal
# NR_FEDERACAO                                                      -1
# NM_FEDERACAO                                                  #NULO#
# SG_FEDERACAO                                                  #NULO#
# DS_COMPOSICAO_FEDERACAO                                       #NULO#
# SQ_COLIGACAO                                            280000050386
# NM_COLIGACAO               BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                   PSL / PRTB
# ST_VOTO_EM_TRANSITO                                                N
# QT_VOTOS_NOMINAIS                                               2918
# NM_TIPO_DESTINACAO_VOTOS                                      Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                       2918
# CD_SIT_TOT_TURNO                                                   1
# DS_SIT_TOT_TURNO                                              ELEITO
#
#                                                              7905926
# DT_GERACAO                                                13/11/2024
# HH_GERACAO                                                  10:56:11
# ANO_ELEICAO                                                     2018
# CD_TIPO_ELEICAO                                                    2
# NM_TIPO_ELEICAO                                    Eleição Ordinária
# NR_TURNO                                                           2
# CD_ELEICAO                                                       296
# DS_ELEICAO                                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                                28/10/2018
# TP_ABRANGENCIA                                                     F
# SG_UF                                                             MA
# SG_UE                                                             BR
# NM_UE                                                         BRASIL
# CD_MUNICIPIO                                                    7676
# NM_MUNICIPIO                                                 COLINAS
# NR_ZONA                                                           29
# CD_CARGO                                                           1
# DS_CARGO                                                  Presidente
# SQ_CANDIDATO                                            280000614517
# NR_CANDIDATO                                                      17
# NM_CANDIDATO                                  JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                           #NULO#
# CD_SITUACAO_CANDIDATURA                                           12
# DS_SITUACAO_CANDIDATURA                                         APTO
# CD_DETALHE_SITUACAO_CAND                                           2
# DS_DETALHE_SITUACAO_CAND                                    DEFERIDO
# CD_SITUACAO_JULGAMENTO                                            -3
# DS_SITUACAO_JULGAMENTO                                           #NE
# CD_SITUACAO_CASSACAO                                              -3
# DS_SITUACAO_CASSACAO                                             #NE
# CD_SITUACAO_DIPLOMA                                               -3
# DS_SITUACAO_DIPLOMA                                              #NE
# TP_AGREMIACAO                                              COLIGAÇÃO
# NR_PARTIDO                                                        17
# SG_PARTIDO                                                       PSL
# NM_PARTIDO                                    Partido Social Liberal
# NR_FEDERACAO                                                      -1
# NM_FEDERACAO                                                  #NULO#
# SG_FEDERACAO                                                  #NULO#
# DS_COMPOSICAO_FEDERACAO                                       #NULO#
# SQ_COLIGACAO                                            280000050386
# NM_COLIGACAO               BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                   PSL / PRTB
# ST_VOTO_EM_TRANSITO                                                N
# QT_VOTOS_NOMINAIS                                               2917
# NM_TIPO_DESTINACAO_VOTOS                                      Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                       2917
# CD_SIT_TOT_TURNO                                                   1
# DS_SIT_TOT_TURNO                                              ELEITO

# %%
# Vamos verificar quantos municipios unicos existem no conjunto de dados
# Vamos pegar por codigo do municipio
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5708

# %%
# Mas o Brasil tem 5570 municipios
# Vamos verificar algumas cidades fora do Brasil
df_votacao[df_votacao['SG_UF'] == 'ZZ'].sample(4).T
# Out:
#                                               8057715  \
# DT_GERACAO                                 13/11/2024
# HH_GERACAO                                   10:56:11
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    30457
# NM_MUNICIPIO                                 ROTTERDÃ
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# CD_SITUACAO_JULGAMENTO                             -3
# DS_SITUACAO_JULGAMENTO                            #NE
# CD_SITUACAO_CASSACAO                               -3
# DS_SITUACAO_CASSACAO                              #NE
# CD_SITUACAO_DIPLOMA                                -3
# DS_SITUACAO_DIPLOMA                               #NE
# TP_AGREMIACAO                               COLIGAÇÃO
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                1047
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                        1047
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO
#
#                                               8057747  \
# DT_GERACAO                                 13/11/2024
# HH_GERACAO                                   10:56:11
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    29327
# NM_MUNICIPIO                                 ASSUNÇÃO
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# CD_SITUACAO_JULGAMENTO                             -3
# DS_SITUACAO_JULGAMENTO                            #NE
# CD_SITUACAO_CASSACAO                               -3
# DS_SITUACAO_CASSACAO                              #NE
# CD_SITUACAO_DIPLOMA                                -3
# DS_SITUACAO_DIPLOMA                               #NE
# TP_AGREMIACAO                               COLIGAÇÃO
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                 213
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                         213
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO
#
#                                               8014107  \
# DT_GERACAO                                 13/11/2024
# HH_GERACAO                                   10:56:11
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    29670
# NM_MUNICIPIO                              ENCARNACIÓN
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# CD_SITUACAO_JULGAMENTO                             -3
# DS_SITUACAO_JULGAMENTO                            #NE
# CD_SITUACAO_CASSACAO                               -3
# DS_SITUACAO_CASSACAO                              #NE
# CD_SITUACAO_DIPLOMA                                -3
# DS_SITUACAO_DIPLOMA                               #NE
# TP_AGREMIACAO                               COLIGAÇÃO
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                  18
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                          18
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO
#
#                                               8047794
# DT_GERACAO                                 13/11/2024
# HH_GERACAO                                   10:56:11
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    30104
# NM_MUNICIPIO                              MÉXICO-MEXI
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# CD_SITUACAO_JULGAMENTO                             -3
# DS_SITUACAO_JULGAMENTO                            #NE
# CD_SITUACAO_CASSACAO                               -3
# DS_SITUACAO_CASSACAO                              #NE
# CD_SITUACAO_DIPLOMA                                -3
# DS_SITUACAO_DIPLOMA                               #NE
# TP_AGREMIACAO                               COLIGAÇÃO
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                 305
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                         305
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO

# %%
# Quantas cidades fora do Brasil estão no conjunto de dados?
df_votacao[df_votacao['SG_UF'] == 'ZZ']['CD_MUNICIPIO'].nunique()
# Out:
# 138

# %%
# Vamos eliminar os municpios de fora do Brasil
df_votacao = df_votacao[df_votacao['SG_UF'] != 'ZZ']

# %%
# Verificando a quantidade de municpios
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5570

# %%
# Os dados estão separados por municipio/zona
# Municipios pequenos normalmente tem apenas 1 zona eleitoral
# mas municipios maiores podem ter várias zonas eleitorias

# Vamos verificar Belo Horizonte
df_votacao[df_votacao['NM_MUNICIPIO'] == 'BELO HORIZONTE']
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 7892473  13/11/2024   10:56:11         2018                2
# 7893064  13/11/2024   10:56:11         2018                2
# 7893356  13/11/2024   10:56:11         2018                2
# 7894240  13/11/2024   10:56:11         2018                2
# 7894263  13/11/2024   10:56:11         2018                2
# ...             ...        ...          ...              ...
# 8102178  13/11/2024   10:56:11         2018                2
# 8102454  13/11/2024   10:56:11         2018                2
# 8102458  13/11/2024   10:56:11         2018                2
# 8102460  13/11/2024   10:56:11         2018                2
# 8102468  13/11/2024   10:56:11         2018                2
#
#            NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO  \
# 7892473  Eleição Ordinária         2         296
# 7893064  Eleição Ordinária         2         296
# 7893356  Eleição Ordinária         2         296
# 7894240  Eleição Ordinária         2         296
# 7894263  Eleição Ordinária         2         296
# ...                    ...       ...         ...
# 8102178  Eleição Ordinária         2         298
# 8102454  Eleição Ordinária         2         298
# 8102458  Eleição Ordinária         2         298
# 8102460  Eleição Ordinária         2         298
# 8102468  Eleição Ordinária         2         298
#
#                              DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  ...  \
# 7892473      ELEIÇÃO GERAL FEDERAL 2018  28/10/2018              F  ...
# 7893064      ELEIÇÃO GERAL FEDERAL 2018  28/10/2018              F  ...
# 7893356      ELEIÇÃO GERAL FEDERAL 2018  28/10/2018              F  ...
# 7894240      ELEIÇÃO GERAL FEDERAL 2018  28/10/2018              F  ...
# 7894263      ELEIÇÃO GERAL FEDERAL 2018  28/10/2018              F  ...
# ...                                 ...         ...            ...  ...
# 8102178  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 8102454  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 8102458  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 8102460  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 8102468  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
#
#         DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO  \
# 7892473                  #NULO#  280000050386
# 7893064                  #NULO#  280000050386
# 7893356                  #NULO#  280000050386
# 7894240                  #NULO#  280000050386
# 7894263                  #NULO#  280000050386
# ...                         ...           ...
# 8102178                  #NULO#  130000050129
# 8102454                  #NULO#  130000050129
# 8102458                  #NULO#  130000050129
# 8102460                  #NULO#  130000050129
# 8102468                  #NULO#  130000050129
#
#                                       NM_COLIGACAO  \
# 7892473  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 7893064  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 7893356  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 7894240  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# 7894263  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# ...                                            ...
# 8102178                          RECONSTRUIR MINAS
# 8102454                          RECONSTRUIR MINAS
# 8102458                          RECONSTRUIR MINAS
# 8102460                          RECONSTRUIR MINAS
# 8102468                          RECONSTRUIR MINAS
#
#                                    DS_COMPOSICAO_COLIGACAO  \
# 7892473                                         PSL / PRTB
# 7893064                                         PSL / PRTB
# 7893356                                         PSL / PRTB
# 7894240                                         PSL / PRTB
# 7894263                                         PSL / PRTB
# ...                                                    ...
# 8102178  PSDB / PSD / SOLIDARIEDADE / PTB / PPS / PMN /...
# 8102454  PSDB / PSD / SOLIDARIEDADE / PTB / PPS / PMN /...
# 8102458  PSDB / PSD / SOLIDARIEDADE / PTB / PPS / PMN /...
# 8102460  PSDB / PSD / SOLIDARIEDADE / PTB / PPS / PMN /...
# 8102468  PSDB / PSD / SOLIDARIEDADE / PTB / PPS / PMN /...
#
#         ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  NM_TIPO_DESTINACAO_VOTOS  \
# 7892473                   N              55333                    Válido
# 7893064                   N              44233                    Válido
# 7893356                   N              59381                    Válido
# 7894240                   N              44471                    Válido
# 7894263                   N              43886                    Válido
# ...                     ...                ...                       ...
# 8102178                   N              28017                    Válido
# 8102454                   N              26207                    Válido
# 8102458                   N              36485                    Válido
# 8102460                   N              23187                    Válido
# 8102468                   N              30153                    Válido
#
#         QT_VOTOS_NOMINAIS_VALIDOS  CD_SIT_TOT_TURNO  DS_SIT_TOT_TURNO
# 7892473                     55333                 1            ELEITO
# 7893064                     44233                 1            ELEITO
# 7893356                     59381                 1            ELEITO
# 7894240                     44471                 1            ELEITO
# 7894263                     43886                 1            ELEITO
# ...                           ...               ...               ...
# 8102178                     28017                 4        NÃO ELEITO
# 8102454                     26207                 4        NÃO ELEITO
# 8102458                     36485                 4        NÃO ELEITO
# 8102460                     23187                 4        NÃO ELEITO
# 8102468                     30153                 4        NÃO ELEITO
#
# [72 rows x 50 columns]

# %%
# Eliminar algumas colunas do dataframe que não serão utilizadas
df_votacao = df_votacao[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO',
                        'NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]

df_votacao.head()
# Out:
#         SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_CANDIDATO  \
# 7862039    RS         89141         CAPÃO DO CIPÓ            17
# 7862040    RS         85707             SEDE NOVA            17
# 7862041    RS         88935  SÃO SEBASTIÃO DO CAÍ            17
# 7862042    RS         87378                 MARAU            17
# 7862043    RS         86010           CERRO LARGO            17
#
#         NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 7862039    JAIR BOLSONARO                943
# 7862040    JAIR BOLSONARO               1015
# 7862041    JAIR BOLSONARO               8758
# 7862042    JAIR BOLSONARO              17922
# 7862043    JAIR BOLSONARO               4149

# %%
# Precisamos agregar os dados por municipio e candidato
df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum()
# Out:
#                                                                           QT_VOTOS_NOMINAIS
# SG_UF CD_MUNICIPIO NM_MUNICIPIO           NR_CANDIDATO NM_URNA_CANDIDATO
# AC    1007         BUJARI                 13           FERNANDO HADDAD                 1274
#                                           17           JAIR BOLSONARO                  4676
#       1015         CAPIXABA               13           FERNANDO HADDAD                 1086
#                                           17           JAIR BOLSONARO                  3895
#       1023         PORTO ACRE             13           FERNANDO HADDAD                 2059
# ...                                                                                     ...
# TO    96954        ALIANÇA DO TOCANTINS   17           JAIR BOLSONARO                  1215
#       96970        APARECIDA DO RIO NEGRO 13           FERNANDO HADDAD                 1291
#                                           17           JAIR BOLSONARO                  1171
#       96997        BARROLÂNDIA            13           FERNANDO HADDAD                 1545
#                                           17           JAIR BOLSONARO                  1501
#
# [17126 rows x 1 columns]

# %%
# Fazer o groupby, reindexar o indice, vai salvar isso em um dataframe
df_votacao = df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum().reset_index()

df_votacao.sample(4)
# Out:
#      SG_UF  CD_MUNICIPIO                NM_MUNICIPIO  NR_CANDIDATO  \
# 2442    MA          7145                  BACURITUBA            13
# 350     AM          2453                      JAPURÁ            17
# 5956    MG         52957  SÃO SEBASTIÃO DO RIO PRETO            13
# 8468    PI         11177               MANOEL EMÍDIO            13
#
#      NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 2442   FERNANDO HADDAD               2728
# 350     JAIR BOLSONARO                648
# 5956   FERNANDO HADDAD                425
# 8468   FERNANDO HADDAD               2687

# %%
# Vamos verificar novamente a cidade de Belo Horizonte
df_votacao[df_votacao['NM_MUNICIPIO'] == 'BELO HORIZONTE']
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  NM_URNA_CANDIDATO  \
# 3340    MG         41238  BELO HORIZONTE            13    FERNANDO HADDAD
# 3341    MG         41238  BELO HORIZONTE            17     JAIR BOLSONARO
# 3342    MG         41238  BELO HORIZONTE            30         ROMEU ZEMA
# 3343    MG         41238  BELO HORIZONTE            45  ANTONIO ANASTASIA
#
#       QT_VOTOS_NOMINAIS
# 3340             472887
# 3341             901513
# 3342             773454
# 3343             537931

# %%
# Ordenar o dataframe pela quantidade de votos e depois deixar apenas o primeiro
# registro de cada municipio
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False).head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 16569    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 16570    SP         71072       SÃO PAULO            40     MARCIO FRANÇA
# 16571    SP         71072       SÃO PAULO            45        JOÃO DORIA
# 16568    SP         71072       SÃO PAULO            13   FERNANDO HADDAD
# 9861     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 9863     RJ         60011  RIO DE JANEIRO            25      EDUARDO PAES
# 9862     RJ         60011  RIO DE JANEIRO            20     WILSON WITZEL
# 9860     RJ         60011  RIO DE JANEIRO            13   FERNANDO HADDAD
# 1764     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1763     DF         97012        BRASÍLIA            15           IBANEIS
#
#        QT_VOTOS_NOMINAIS
# 16569            3694834
# 16570            3393092
# 16571            2447309
# 16568            2424125
# 9861             2179896
# 9863             1627367
# 9862             1520888
# 9860             1105393
# 1764             1080411
# 1763             1042574

# %%
# Vamos ordenar
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False, inplace=True)

# dropar as linhas duplicadas, mantendo a primeira
df_votacao.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)

df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 16569    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 9861     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 1764     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1210     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 3341     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 8969     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1532     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 371      AM          2550          MANAUS            20       WILSON LIMA
# 2171     GO         93734         GOIÂNIA            17    JAIR BOLSONARO
# 8144     PE         25313          RECIFE            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS
# 16569            3694834
# 9861             2179896
# 1764             1080411
# 1210              985532
# 3341              901513
# 8969              786377
# 1532              739265
# 371               702863
# 2171              528525
# 8144              482673

# %%
# Vamos verificar novamente a cidade de Belo Horizonte
df_votacao[df_votacao['NM_MUNICIPIO'] == 'BELO HORIZONTE']
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 3341    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
#
#       QT_VOTOS_NOMINAIS
# 3341             901513

# %%
# Agora vamos criar uma coluna representando o resultado da eleição naquele municipio
# sendo que o Resultado é True se o candidato Bolsonaro venceu naquele municipio
# e False em caso contrário
df_votacao['RESULTADO'] = df_votacao['NR_CANDIDATO'].apply(lambda x: x == 17)

# %%
# Verificando o resultado
df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 16569    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 9861     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 1764     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1210     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 3341     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 8969     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1532     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 371      AM          2550          MANAUS            20       WILSON LIMA
# 2171     GO         93734         GOIÂNIA            17    JAIR BOLSONARO
# 8144     PE         25313          RECIFE            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS  RESULTADO
# 16569            3694834       True
# 9861             2179896       True
# 1764             1080411       True
# 1210              985532      False
# 3341              901513       True
# 8969              786377       True
# 1532              739265      False
# 371               702863      False
# 2171              528525       True
# 8144              482673      False

# %%
# Mostrando alguns valores do dataframe do geopandas
df_mapa.sample(3)
# Out:
#                  NM_MUNICIP CD_GEOCMU  \
# 3794           CARLOS GOMES   4304853
# 3038  SANTA BÁRBARA DO PARÁ   1506351
# 1648           OSVALDO CRUZ   3534609
#
#                                                geometry
# 3794  POLYGON ((-51.97585 -27.68599, -51.97348 -27.6...
# 3038  POLYGON ((-48.33423 -1.19742, -48.33251 -1.194...
# 1648  POLYGON ((-50.92912 -21.76656, -50.92907 -21.7...

# %%
# tentando encontrar o municipio pelo código
df_votacao[df_votacao['CD_MUNICIPIO'] == 3156700]
# Out:
# Empty DataFrame
# Columns: [SG_UF, CD_MUNICIPIO, NM_MUNICIPIO, NR_CANDIDATO, NM_URNA_CANDIDATO, QT_VOTOS_NOMINAIS, RESULTADO]
# Index: []

# %%
# Porque não podemos usar o nome do municipio para juntar
df_votacao[df_votacao['NM_MUNICIPIO'] == 'OURO BRANCO']
# Out:
#       SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 5202     MG         49174  OURO BRANCO            30        ROMEU ZEMA
# 174      AL         28215  OURO BRANCO            13   FERNANDO HADDAD
# 10266    RN         17698  OURO BRANCO            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS  RESULTADO
# 5202               15317      False
# 174                 5156      False
# 10266               2463      False

# %%
# Recuperar a tabela de correspondencia entre IBGE e TSE
# direto do github do Estadão
link = 'https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv'

df_equivalencia = pd.read_csv(link)

df_equivalencia.head()
# Out:
#              chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0    ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1  ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 2     ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 3        ac bujari        BUJARI  AC      1200138     1007    NaN
# 4      ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
# Vamos preparar os dataframes

# %%
# Vamos reindexar o dataframe de votação pelo código do TSE
df_vot_novo = df_votacao.copy()

df_vot_novo.set_index('CD_MUNICIPIO', drop=False, inplace=True)

df_vot_novo.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO            17
# 60011           RJ         60011  RIO DE JANEIRO            17
# 97012           DF         97012        BRASÍLIA            17
# 38490           BA         38490        SALVADOR            13
# 41238           MG         41238  BELO HORIZONTE            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO
# 71072           JAIR BOLSONARO            3694834       True
# 60011           JAIR BOLSONARO            2179896       True
# 97012           JAIR BOLSONARO            1080411       True
# 38490          FERNANDO HADDAD             985532      False
# 41238           JAIR BOLSONARO             901513       True

# %%
# Vamos reindexar o dataframe de Equivalencia pelo Código do TSE
df_equi_novo = df_equivalencia.copy()

df_equi_novo.set_index('COD_TSE', drop=False, inplace=True)

df_equi_novo.head()
# Out:
#                    chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# COD_TSE
# 1120       ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1570     ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 1058        ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 1007           ac bujari        BUJARI  AC      1200138     1007    NaN
# 1015         ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
# Verificando o tamanho dos dataframes
df_vot_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 71072 to 90239
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   int64
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NR_CANDIDATO       5570 non-null   int64
#  4   NM_URNA_CANDIDATO  5570 non-null   object
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 310.0+ KB

# %%
df_equi_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 1120 to 96431
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chave        5570 non-null   object
#  1   NOME         5570 non-null   object
#  2   UF           5570 non-null   object
#  3   GEOCOD_IBGE  5570 non-null   int64
#  4   COD_TSE      5570 non-null   int64
#  5   AJUSTE       29 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 304.6+ KB

# %%
# Criando um novo dataframe com base no merge de Votação e Equivalencia
df_vot_equi = df_vot_novo.join(df_equi_novo)

df_vot_equi.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO            17
# 60011           RJ         60011  RIO DE JANEIRO            17
# 97012           DF         97012        BRASÍLIA            17
# 38490           BA         38490        SALVADOR            13
# 41238           MG         41238  BELO HORIZONTE            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO  \
# CD_MUNICIPIO
# 71072           JAIR BOLSONARO            3694834       True
# 60011           JAIR BOLSONARO            2179896       True
# 97012           JAIR BOLSONARO            1080411       True
# 38490          FERNANDO HADDAD             985532      False
# 41238           JAIR BOLSONARO             901513       True
#
#                           chave            NOME  UF  GEOCOD_IBGE  COD_TSE  \
# CD_MUNICIPIO
# 71072              sp sao paulo       SÃO PAULO  SP      3550308    71072
# 60011         rj rio de janeiro  RIO DE JANEIRO  RJ      3304557    60011
# 97012               df brasilia        BRASÍLIA  DF      5300108    97012
# 38490               ba salvador        SALVADOR  BA      2927408    38490
# 41238         mg belo horizonte  BELO HORIZONTE  MG      3106200    41238
#
#              AJUSTE
# CD_MUNICIPIO
# 71072           NaN
# 60011           NaN
# 97012           NaN
# 38490           NaN
# 41238           NaN

# %%
# Vamos juntar o dataframe do GeoPandas com o dataframe Votação/Equivalência

# %%
df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   int64
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NR_CANDIDATO       5570 non-null   int64
#  4   NM_URNA_CANDIDATO  5570 non-null   object
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
#  7   chave              5570 non-null   object
#  8   NOME               5570 non-null   object
#  9   UF                 5570 non-null   object
#  10  GEOCOD_IBGE        5570 non-null   int64
#  11  COD_TSE            5570 non-null   int64
#  12  AJUSTE             29 non-null     object
# dtypes: bool(1), int64(5), object(7)
# memory usage: 700.2+ KB

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NM_MUNICIP  5572 non-null   object
#  1   CD_GEOCMU   5572 non-null   object
#  2   geometry    5572 non-null   geometry
# dtypes: geometry(1), object(2)
# memory usage: 130.7+ KB

# %%
# Transformar a coluna de codigo de IBGE do dataframe de Votação/Equivalência
df_vot_equi['GEOCOD_IBGE'] = df_vot_equi['GEOCOD_IBGE'].astype(str)

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   int64
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NR_CANDIDATO       5570 non-null   int64
#  4   NM_URNA_CANDIDATO  5570 non-null   object
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
#  7   chave              5570 non-null   object
#  8   NOME               5570 non-null   object
#  9   UF                 5570 non-null   object
#  10  GEOCOD_IBGE        5570 non-null   object
#  11  COD_TSE            5570 non-null   int64
#  12  AJUSTE             29 non-null     object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 700.2+ KB

# %%
df_mapa.head()
# Out:
#               NM_MUNICIP CD_GEOCMU  \
# 0     CACHOEIRA DO PIRIÁ   1501956
# 1  SÃO JOSÉ DOS BASÍLIOS   2111250
# 2  APARECIDA DO RIO DOCE   5201454
# 3             ARENÓPOLIS   5202353
# 4                  CURUÁ   1502855
#
#                                             geometry
# 0  POLYGON ((-46.31955 -1.75518, -46.3199 -1.7557...
# 1  POLYGON ((-44.63409 -5.03498, -44.63407 -5.034...
# 2  POLYGON ((-51.1423 -18.29672, -51.14236 -18.29...
# 3  POLYGON ((-51.69953 -16.2327, -51.69957 -16.23...
# 4  POLYGON ((-55.17193 -1.83331, -55.16647 -1.731...

# %%
# Vamos unificar os indices

# Mudando o indice do dataframe de Mapa
df_mapa.set_index('CD_GEOCMU', drop=False, inplace=True)

# %%
# Mudando o indice do dataframe de Votação/Equivalência
df_vot_equi.set_index('GEOCOD_IBGE', drop=False, inplace=True)

# %%
# Vamos juntar os dataframes
df_mapa_novo = df_mapa.join(df_vot_equi)

df_mapa_novo.head().T
# Out:
# CD_GEOCMU                                                    1501956  \
# NM_MUNICIP                                        CACHOEIRA DO PIRIÁ
# CD_GEOCMU                                                    1501956
# geometry           POLYGON ((-46.31955231999996 -1.75517617399992...
# SG_UF                                                             PA
# CD_MUNICIPIO                                                  4766.0
# NM_MUNICIPIO                                      CACHOEIRA DO PIRIÁ
# NR_CANDIDATO                                                    13.0
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                             6460.0
# RESULTADO                                                      False
# chave                                          pa cachoeira do piria
# NOME                                              CACHOEIRA DO PIRIÁ
# UF                                                                PA
# GEOCOD_IBGE                                                  1501956
# COD_TSE                                                       4766.0
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    2111250  \
# NM_MUNICIP                                     SÃO JOSÉ DOS BASÍLIOS
# CD_GEOCMU                                                    2111250
# geometry           POLYGON ((-44.634092315999965 -5.0349752749999...
# SG_UF                                                             MA
# CD_MUNICIPIO                                                  8362.0
# NM_MUNICIPIO                                   SÃO JOSÉ DOS BASÍLIOS
# NR_CANDIDATO                                                    13.0
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                             3743.0
# RESULTADO                                                      False
# chave                                       ma sao jose dos basilios
# NOME                                           SÃO JOSÉ DOS BASÍLIOS
# UF                                                                MA
# GEOCOD_IBGE                                                  2111250
# COD_TSE                                                       8362.0
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    5201454  \
# NM_MUNICIP                                     APARECIDA DO RIO DOCE
# CD_GEOCMU                                                    5201454
# geometry           POLYGON ((-51.14229517499996 -18.2967249689999...
# SG_UF                                                             GO
# CD_MUNICIPIO                                                 93009.0
# NM_MUNICIPIO                                   APARECIDA DO RIO DOCE
# NR_CANDIDATO                                                    17.0
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# QT_VOTOS_NOMINAIS                                              873.0
# RESULTADO                                                       True
# chave                                       go aparecida do rio doce
# NOME                                           APARECIDA DO RIO DOCE
# UF                                                                GO
# GEOCOD_IBGE                                                  5201454
# COD_TSE                                                      93009.0
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    5202353  \
# NM_MUNICIP                                                ARENÓPOLIS
# CD_GEOCMU                                                    5202353
# geometry           POLYGON ((-51.69953044199997 -16.2326965739999...
# SG_UF                                                             GO
# CD_MUNICIPIO                                                 96717.0
# NM_MUNICIPIO                                              ARENÓPOLIS
# NR_CANDIDATO                                                    13.0
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                             1157.0
# RESULTADO                                                      False
# chave                                                  go arenopolis
# NOME                                                      ARENÓPOLIS
# UF                                                                GO
# GEOCOD_IBGE                                                  5202353
# COD_TSE                                                      96717.0
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    1502855
# NM_MUNICIP                                                     CURUÁ
# CD_GEOCMU                                                    1502855
# geometry           POLYGON ((-55.17192719299993 -1.83330502899997...
# SG_UF                                                             PA
# CD_MUNICIPIO                                                  4740.0
# NM_MUNICIPIO                                                   CURUÁ
# NR_CANDIDATO                                                    13.0
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                             5629.0
# RESULTADO                                                      False
# chave                                                       pa curua
# NOME                                                           CURUÁ
# UF                                                                PA
# GEOCOD_IBGE                                                  1502855
# COD_TSE                                                       4740.0
# AJUSTE                                                           NaN

# %%
# Verificando o tamanho do mapa novo
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 1501956 to 2611705
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NM_MUNICIP         5572 non-null   object
#  1   CD_GEOCMU          5572 non-null   object
#  2   geometry           5572 non-null   geometry
#  3   SG_UF              5570 non-null   object
#  4   CD_MUNICIPIO       5570 non-null   float64
#  5   NM_MUNICIPIO       5570 non-null   object
#  6   NR_CANDIDATO       5570 non-null   float64
#  7   NM_URNA_CANDIDATO  5570 non-null   object
#  8   QT_VOTOS_NOMINAIS  5570 non-null   float64
#  9   RESULTADO          5570 non-null   object
#  10  chave              5570 non-null   object
#  11  NOME               5570 non-null   object
#  12  UF                 5570 non-null   object
#  13  GEOCOD_IBGE        5570 non-null   object
#  14  COD_TSE            5570 non-null   float64
#  15  AJUSTE             29 non-null     object
# dtypes: float64(4), geometry(1), object(11)
# memory usage: 869.1+ KB

# %%
# Vamos descobrir os 2 municipios a mais no mapa
df_mapa_novo[df_mapa_novo['NR_CANDIDATO'].isnull()]
# Out:
#                 NM_MUNICIP CD_GEOCMU  \
# CD_GEOCMU
# 4300001        LAGOA MIRIM   4300001
# 4300002    LAGOA DOS PATOS   4300002
#
#                                                     geometry SG_UF  \
# CD_GEOCMU
# 4300001    POLYGON ((-52.62241 -32.14662, -52.62802 -32.1...   NaN
# 4300002    POLYGON ((-51.2719 -30.03897, -51.27064 -30.03...   NaN
#
#            CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# CD_GEOCMU
# 4300001             NaN          NaN           NaN               NaN
# 4300002             NaN          NaN           NaN               NaN
#
#            QT_VOTOS_NOMINAIS RESULTADO chave NOME   UF GEOCOD_IBGE  COD_TSE  \
# CD_GEOCMU
# 4300001                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300002                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
#
#           AJUSTE
# CD_GEOCMU
# 4300001      NaN
# 4300002      NaN

# %%
# Matar a coluna ajuste
df_mapa_novo.drop(columns=['AJUSTE'], inplace=True)

# %%
# Vamos eliminar a informação das duas lagoas do RS
df_mapa_novo.dropna(inplace=True)

# %%
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5570 entries, 1501956 to 2611705
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NM_MUNICIP         5570 non-null   object
#  1   CD_GEOCMU          5570 non-null   object
#  2   geometry           5570 non-null   geometry
#  3   SG_UF              5570 non-null   object
#  4   CD_MUNICIPIO       5570 non-null   float64
#  5   NM_MUNICIPIO       5570 non-null   object
#  6   NR_CANDIDATO       5570 non-null   float64
#  7   NM_URNA_CANDIDATO  5570 non-null   object
#  8   QT_VOTOS_NOMINAIS  5570 non-null   float64
#  9   RESULTADO          5570 non-null   object
#  10  chave              5570 non-null   object
#  11  NOME               5570 non-null   object
#  12  UF                 5570 non-null   object
#  13  GEOCOD_IBGE        5570 non-null   object
#  14  COD_TSE            5570 non-null   float64
# dtypes: float64(4), geometry(1), object(10)
# memory usage: 696.2+ KB

# %%
# Vamos desenhar o mapa

# Criar a referência para o código de cor (False/0 = red, True/1 = green)
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['red', 'green'])

# Desenhando o mapa
fig, ax = plt.subplots(1, figsize=(12, 12))

ax = df_mapa_novo.plot(column='RESULTADO', cmap=cmap, legend=True, linewidth=0.1, ax=ax,
                      edgecolor='grey')

# Escondendo o eixos
ax.set_axis_off()

# Colocando um título
ax.set_title('Resultado Eleição 2018 por Município / 2º Turno', fontdict={'fontsize': '25', 'fontweight': '3'})

# Criando uma nota do rodapé
ax.annotate('Fonte: IBGE, 2015; TSE, 2019; Jornal o Estado de São Paulo, 2019',
    xy=(0.1, 0.08), xycoords='figure fraction', horizontalalignment='left',
    verticalalignment='top', fontsize=10, color='#555555')

# Alterando a legenda
leg = ax.get_legend()
leg.get_texts()[0].set_text('Fernando Haddad')
leg.get_texts()[1].set_text('Jair Bolsonaro')

plt.show()
